# %%
import requests
from bs4 import BeautifulSoup
from tenacity import retry, wait_fixed, stop_after_attempt, retry_if_exception_type
import json

# Define headers to mimic a browser request
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'Connection': 'keep-alive',
    'Upgrade-Insecure-Requests': '1'
}

@retry(wait=wait_fixed(2), stop=stop_after_attempt(3), retry=retry_if_exception_type(requests.exceptions.RequestException))
def fetch_url(url):
    response = requests.get(url, headers=headers)
    response.raise_for_status()  # Raise an HTTPError for bad responses
    return response.content

def extract_address_from_script(script_content):
    # Look for the "onEmbedLoad" function
    if "function onEmbedLoad()" in script_content:
        lines = script_content.splitlines()
        for line in lines:
            if '"/maps/embed/record204"' in line:
                # Skip everything before "/maps/embed/record204"
                parts = line.split('"/maps/embed/record204"')[1].split('"')
                if len(parts) > 1:
                    return parts[5]
    return "Address not found in script."

def get_address_from_iframe(url):
    try:
        # Step 1: Fetch the HTML content of the main page
        print(f"Fetching main page content from {url}...")
        main_page_content = fetch_url(url)
        
        # Step 2: Parse the HTML to find the iframe
        print("Parsing main page content...")
        soup = BeautifulSoup(main_page_content, 'html.parser')
        iframe_tag = soup.find('iframe', src=True)

        if iframe_tag:
            iframe_url = iframe_tag['src']
            print(f"Iframe URL found: {iframe_url}")

            # Step 3: Fetch the iframe content
            print("Fetching iframe content...")
            iframe_content = fetch_url(iframe_url)

            # Step 4: Parse the iframe HTML to extract the address
            print("Parsing iframe content...")
            iframe_soup = BeautifulSoup(iframe_content, 'html.parser')

            # Extract the script content
            script_tag = iframe_soup.find('script', text=lambda text: text and 'onEmbedLoad' in text)
            if script_tag:
                script_content = script_tag.get_text()
                address = extract_address_from_script(script_content)
                return address
            else:
                return "none"
        else:
            return "null"
    except requests.exceptions.RequestException as e:
        return f"Error fetching the URL: {e}"

def process_theme_parks(file_path):
    with open(file_path, 'r') as file:
        theme_parks = json.load(file)

    results = []

    for park in theme_parks:
        url = park['link']
        details = park['details']
        address = get_address_from_iframe(url)
        
        result = {
            'title': details['title'],
            'image': details['image'],
            'introText': details['introText'],
            'mapLink': details['mapLink'],
            'Address': address
        }
        results.append(result)

    with open('59.Data.json', 'w') as outfile:
        json.dump(results, outfile, indent=4)

# Example usage
process_theme_parks('theme_parks_details.json')
# Out:
# Fetching main page content from https://www.themeparks-uk.com/uk-theme-parks/england/adventure-island...
# Parsing main page content...
# Iframe URL found: https://maps.google.co.uk/maps?q=adventure+island&oe=utf-8&client=firefox-a&channel=sb&ie=UTF8&hq=&hnear=&ll=51.532394,0.716916&spn=0.006295,0.006295&t=h&iwloc=A&output=embed
# Fetching iframe content...
# Parsing iframe content...
# Fetching main page content from https://www.themeparks-uk.com/uk-theme-parks/england/adventure-wonderland...
# Parsing main page content...
# Iframe URL found: https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d1623.3048089362055!2d-1.8452566424510355!3d50.775162471816984!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x487398e13af9a715%3A0x15f1acb138e4c5a8!2sAdventure+Wonderland!5e1!3m2!1sen!2suk!4v1494175585303
# Fetching iframe content...
# Parsing iframe content...
# Fetching main page content from https://www.themeparks-uk.com/uk-theme-parks/wales/barry-island-pleasure-park...
# Parsing main page content...
# Iframe URL found: https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d1913.486885623704!2d-3.2750949154006492!3d51.39158536926824!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x486e05fb74864843%3A0x5cda027fb5f8598a!2sBarry%20Island%20Pleasure%20Park!5e1!3m2!1sen!2suk!4v1654774933306!5m2!1sen!2suk
# Fetching iframe content...
# Parsing iframe content...
# Fetching main page content from https://www.themeparks-uk.com/uk-theme-parks/england/blackgang-chine...
# Parsing main page content...
# Iframe URL found: https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d12124.819664919756!2d-1.3241666224068014!3d50.587154619504126!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x4874867566985967%3A0xed49f3c58b269383!2sBlackgang%20Chine!5e1!3m2!1sen!2suk!4v1708604726771!5m2!1sen!2suk
# Fetching iframe content...
# Parsing iframe content...
# Fetching main page content from https://www.themeparks-uk.com/uk-theme-parks/england/brean-theme-park...
# Parsing main page content...
# Iframe URL found: https://maps.google.co.uk/maps?q=brean+leisure+park&oe=utf-8&client=firefox-a&channel=sb&ie=UTF8&hq=&hnear=&ll=51.285462,-3.010563&spn=0.006295,0.006295&t=h&iwloc=A&output=embed
# Fetching iframe content...
# Parsing iframe content...
# Fetching main page content from https://www.themeparks-uk.com/uk-theme-parks/england/camel-creek-family-adventure-park...
# Parsing main page content...
# Iframe URL found: https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d2261.8168400715936!2d-4.931790660061178!3d50.48877954234847!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x486b749f6e9a74d1%3A0xaadb28c7bc9cf6c1!2sCamel+Creek+Adventure+Park!5e1!3m2!1sen!2suk!4v1476895237819
# Fetching iframe content...
# Parsing iframe content...
# Fetching main page content from https://www.themeparks-uk.com/uk-theme-parks/scotland/codonas...
# Parsing main page content...
# Fetching main page content from https://www.themeparks-uk.com/uk-theme-parks/england/crealy-theme-park...
# Parsing main page content...
# Iframe URL found: https://www.youtube.com/embed/R5JW-OXwTa4?rel=0&fs=1&wmode=transparent
# Fetching iframe content...
# Parsing iframe content...
# Fetching main page content from https://www.themeparks-uk.com/uk-theme-parks/england/diggerland...
# Parsing main page content...
# Fetching main page content from https://www.themeparks-uk.com/uk-theme-parks/england/dreamland-margate...
# Parsing main page content...
# Iframe URL found: https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d10474.470809076598!2d1.378741267593296!3d51.387973177459486!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x47d953ab94e9f7d1%3A0xa96828d4c398906c!2sDreamland!5e1!3m2!1sen!2suk!4v1434656354553
# Fetching iframe content...
# Parsing iframe content...
# Fetching main page content from https://www.themeparks-uk.com/uk-theme-parks/england/drusillas-park...
# Parsing main page content...
# Fetching main page content from https://www.themeparks-uk.com/uk-theme-parks/england/fantasy-island...
# Parsing main page content...
# Iframe URL found: https://maps.google.co.uk/maps?q=fantasy+island&oe=utf-8&client=firefox-a&channel=sb&ie=UTF8&hq=fantasy+island&ll=53.1925,0.349834&spn=0.007752,0.021136&t=h&z=14&iwloc=A&cid=9664714470081121772&output=embed
# Fetching iframe content...
# Parsing iframe content...
# Fetching main page content from https://www.themeparks-uk.com/uk-theme-parks/england/flambards...
# Parsing main page content...
# Iframe URL found: https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d2366.3731379260084!2d-5.260766684430941!3d50.09222977942753!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x486b278e29e0d79b%3A0xabc5ab6710579c07!2sFlambards!5e1!3m2!1sen!2suk!4v1494176817238
# Fetching iframe content...
# Parsing iframe content...
# Fetching main page content from https://www.themeparks-uk.com/uk-theme-parks/england/flamingo-land...
# Parsing main page content...
# Iframe URL found: https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d8008.321275583981!2d-0.8080010769104273!3d54.21155201430274!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x487f29c9df693dd5%3A0xcdd704370d7e0895!2sFlamingo+Land!5e1!3m2!1sen!2suk!4v1427050973677
# Fetching iframe content...
# Parsing iframe content...
# Fetching main page content from https://www.themeparks-uk.com/uk-theme-parks/england/funland-hayling-island...
# Parsing main page content...
# Fetching main page content from https://www.themeparks-uk.com/uk-theme-parks/england/great-yarmouth-pleasure-beach...
# Parsing main page content...
# Iframe URL found: https://maps.google.co.uk/maps?q=great+yarmouth+pleasure+beach&oe=utf-8&client=firefox-a&channel=sb&ie=UTF8&hq=&hnear=&ll=52.592854,1.735954&spn=0.006295,0.006295&t=h&iwloc=A&output=embed
# Fetching iframe content...
# Parsing iframe content...
# Fetching main page content from https://www.themeparks-uk.com/uk-theme-parks/wales/greenwood...
# Parsing main page content...
# Iframe URL found: https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d114776.0727158108!2d-4.262250796405382!3d53.19167951630547!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x4865a8fded64d0d7%3A0x58b22bdb55761cee!2sGreenWood%20Family%20Park!5e1!3m2!1sen!2suk!4v1618493211378!5m2!1sen!2suk
# Fetching iframe content...
# Parsing iframe content...
# Fetching main page content from https://www.themeparks-uk.com/uk-theme-parks/england/gullivers-kingdom-matlock-bath...
# Parsing main page content...
# Iframe URL found: https://maps.google.co.uk/maps?oe=utf-8&client=firefox-a&channel=sb&q=Gulliver's+Kingdom&ie=UTF8&hq=&hnear=&ll=53.11906,-1.564061&spn=0.006295,0.006295&t=h&iwloc=A&output=embed
# Fetching iframe content...
# Parsing iframe content...
# Fetching main page content from https://www.themeparks-uk.com/uk-theme-parks/england/gullivers-land-milton-keynes...
# Parsing main page content...
# Iframe URL found: https://maps.google.co.uk/maps?q=Gulliver's+Land&oe=utf-8&client=firefox-a&channel=sb&ie=UTF8&hq=&hnear=&ll=52.051125,-0.730046&spn=0.006295,0.006295&t=h&iwloc=A&output=embed
# Fetching iframe content...
# Parsing iframe content...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 94
#      91         json.dump(results, outfile, indent=4)
#      93 # Example usage
# ---> 94 process_theme_parks('theme_parks_details.json')
#
# Cell In[4], line 79, in process_theme_parks(file_path)
#      77 url = park['link']
#      78 details = park['details']
# ---> 79 address = get_address_from_iframe(url)
#      81 result = {
#      82     'title': details['title'],
#      83     'image': details['image'],
#    (...)
#      86     'Address': address
#      87 }
#      88 results.append(result)
#
# Cell In[4], line 61, in get_address_from_iframe(url)
#      59 if script_tag:
#      60     script_content = script_tag.get_text()
# ---> 61     address = extract_address_from_script(script_content)
#      62     return address
#      63 else:
#
# Cell In[4], line 31, in extract_address_from_script(script_content)
#      29             parts = line.split('"/maps/embed/record204"')[1].split('"')
#      30             if len(parts) > 1:
# ---> 31                 return parts[5]
#      32 return "Address not found in script."
#
# IndexError: list index out of range

# %%
import requests
from bs4 import BeautifulSoup
from tenacity import retry, wait_fixed, stop_after_attempt, retry_if_exception_type
import json

# Define headers to mimic a browser request
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36',
    'Accept-Language': 'en-US,en;q=0.9',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'Connection': 'keep-alive',
    'Upgrade-Insecure-Requests': '1'
}

@retry(wait=wait_fixed(2), stop=stop_after_attempt(3), retry=retry_if_exception_type(requests.exceptions.RequestException))
def fetch_url(url):
    response = requests.get(url, headers=headers)
    response.raise_for_status()  # Raise an HTTPError for bad responses
    return response.content

def extract_address_from_script(script_content):
    try:
        # Look for the "onEmbedLoad" function
        if "function onEmbedLoad()" in script_content:
            lines = script_content.splitlines()
            for line in lines:
                if '"/maps/embed/record204"' in line:
                    # Skip everything before "/maps/embed/record204"
                    parts = line.split('"/maps/embed/record204"')[1].split('"')
                    if len(parts) > 5:
                        return parts[5]
    except Exception as e:
        print(f"Error extracting address from script: {e}")
    return None

@retry(wait=wait_fixed(2), stop=stop_after_attempt(3), retry=retry_if_exception_type(Exception))
def get_address_from_iframe(url):
    try:
        # Step 1: Fetch the HTML content of the main page
        print(f"Fetching main page content from {url}...")
        main_page_content = fetch_url(url)
        
        # Step 2: Parse the HTML to find the iframe
        print("Parsing main page content...")
        soup = BeautifulSoup(main_page_content, 'html.parser')
        iframe_tag = soup.find('iframe', src=True)

        if iframe_tag:
            iframe_url = iframe_tag['src']
            print(f"Iframe URL found: {iframe_url}")

            # Step 3: Fetch the iframe content
            print("Fetching iframe content...")
            iframe_content = fetch_url(iframe_url)

            # Step 4: Parse the iframe HTML to extract the address
            print("Parsing iframe content...")
            iframe_soup = BeautifulSoup(iframe_content, 'html.parser')

            # Extract the script content
            script_tag = iframe_soup.find('script', text=lambda text: text and 'onEmbedLoad' in text)
            if script_tag:
                script_content = script_tag.get_text()
                address = extract_address_from_script(script_content)
                return address
            else:
                return None
        else:
            return None
    except requests.exceptions.RequestException as e:
        print(f"Error fetching the URL: {e}")
        return None
    except Exception as e:
        print(f"Error processing iframe: {e}")
        return None

def process_theme_parks(file_path):
    with open(file_path, 'r') as file:
        theme_parks = json.load(file)

    results = []

    for park in theme_parks:
        url = park['link']
        details = park['details']
        address = get_address_from_iframe(url)
        
        result = {
            'title': details['title'],
            'image': details['image'],
            'introText': details['introText'],
            'mapLink': details['mapLink'],
            'Address': address if address else "Address not found"
        }
        results.append(result)

    with open('59.Data.json', 'w') as outfile:
        json.dump(results, outfile, indent=4)

# Example usage
process_theme_parks('theme_parks_details.json')
# Out:
# Fetching main page content from https://www.themeparks-uk.com/uk-theme-parks/england/adventure-island...
# Parsing main page content...
# Iframe URL found: https://maps.google.co.uk/maps?q=adventure+island&oe=utf-8&client=firefox-a&channel=sb&ie=UTF8&hq=&hnear=&ll=51.532394,0.716916&spn=0.006295,0.006295&t=h&iwloc=A&output=embed
# Fetching iframe content...
# Parsing iframe content...
# Fetching main page content from https://www.themeparks-uk.com/uk-theme-parks/england/adventure-wonderland...
# Parsing main page content...
# Iframe URL found: https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d1623.3048089362055!2d-1.8452566424510355!3d50.775162471816984!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x487398e13af9a715%3A0x15f1acb138e4c5a8!2sAdventure+Wonderland!5e1!3m2!1sen!2suk!4v1494175585303
# Fetching iframe content...
# Parsing iframe content...
# Fetching main page content from https://www.themeparks-uk.com/uk-theme-parks/wales/barry-island-pleasure-park...
# Parsing main page content...
# Iframe URL found: https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d1913.486885623704!2d-3.2750949154006492!3d51.39158536926824!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x486e05fb74864843%3A0x5cda027fb5f8598a!2sBarry%20Island%20Pleasure%20Park!5e1!3m2!1sen!2suk!4v1654774933306!5m2!1sen!2suk
# Fetching iframe content...
# Parsing iframe content...
# Fetching main page content from https://www.themeparks-uk.com/uk-theme-parks/england/blackgang-chine...
# Parsing main page content...
# Iframe URL found: https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d12124.819664919756!2d-1.3241666224068014!3d50.587154619504126!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x4874867566985967%3A0xed49f3c58b269383!2sBlackgang%20Chine!5e1!3m2!1sen!2suk!4v1708604726771!5m2!1sen!2suk
# Fetching iframe content...
# Parsing iframe content...
# Fetching main page content from https://www.themeparks-uk.com/uk-theme-parks/england/brean-theme-park...
# Parsing main page content...
# Iframe URL found: https://maps.google.co.uk/maps?q=brean+leisure+park&oe=utf-8&client=firefox-a&channel=sb&ie=UTF8&hq=&hnear=&ll=51.285462,-3.010563&spn=0.006295,0.006295&t=h&iwloc=A&output=embed
# Fetching iframe content...
# Parsing iframe content...
# Fetching main page content from https://www.themeparks-uk.com/uk-theme-parks/england/camel-creek-family-adventure-park...
# Parsing main page content...
# Iframe URL found: https://www.google.com/maps/embed?pb=!1m18!1m12!1m3!1d2261.8168400715936!2d-4.931790660061178!3d50.48877954234847!2m3!1f0!2f0!3f0!3m2!1i1024!2i768!4f13.1!3m3!1m2!1s0x486b749f6e9a74d1%3A0xaadb28c7bc9cf6c1!2sCamel+Creek+Adventure+Park!5e1!3m2!1sen!2suk!4v1476895237819
# Fetching iframe content...
# Parsing iframe content...
# Fetching main page content from https://www.themeparks-uk.com/uk-theme-parks/scotland/codonas...
# Parsing main page content...
# Fetching main page content from https://www.themeparks-uk.com/uk-theme-parks/england/crealy-theme-park...
# Parsing main page content...
# Iframe URL found: https://www.youtube.com/embed/R5JW-OXwTa4?rel=0&fs=1&wmode=transparent
# Fetching iframe content...
# Parsing iframe content...
# Fetching main page content from https://www.themeparks-uk.com/uk-theme-parks/england